# %%
print("Hello")
# Out:
# Hello

# %%
print("How are you")
# Out:
# How are you

# %%
def greetings():
    print("Good Evening, How are you!")

# %%
greetings()
# Out:
# Good Evening, How are you!

# %%
greetings()
# Out:
# Good Evening, How are you!
